# %% [markdown]
# ## Pandas Dataframework

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')

print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print(df.tail(3))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
df = pd.read_csv('pokemon_data.csv',delimiter=',')

print(df.head(10))
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
df.columns #Read header
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(df['Name'][0:11]) #Read columns
# Out:
# 0                     Bulbasaur
# 1                       Ivysaur
# 2                      Venusaur
# 3         VenusaurMega Venusaur
# 4                    Charmander
# 5                    Charmeleon
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 9                      Squirtle
# 10                    Wartortle
# Name: Name, dtype: object

# %%
print(df[['Name','Speed']][0:11])
# Out:
#                          Name  Speed
# 0                   Bulbasaur     45
# 1                     Ivysaur     60
# 2                    Venusaur     80
# 3       VenusaurMega Venusaur     80
# 4                  Charmander     65
# 5                  Charmeleon     80
# 6                   Charizard    100
# 7   CharizardMega Charizard X    100
# 8   CharizardMega Charizard Y    100
# 9                    Squirtle     43
# 10                  Wartortle     58

# %%
print(df.iloc[6]) #Read each row
# Out:
# #                     6
# Name          Charizard
# Type 1             Fire
# Type 2           Flying
# HP                   78
# Attack               84
# Defense              78
# Sp. Atk             109
# Sp. Def              85
# Speed               100
# Generation            1
# Legendary         False
# Name: 6, dtype: object

# %%
print(df.iloc[1:5])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print(df.iloc[5,7]) #Read specific loacation
# Out:
# 80

# %%
for index, row in df.iterrows():
   print(index,row[['Name','Speed']])
# Out:
# 0 Name     Bulbasaur
# Speed           45
# Name: 0, dtype: object
# 1 Name     Ivysaur
# Speed         60
# Name: 1, dtype: object
# 2 Name     Venusaur
# Speed          80
# Name: 2, dtype: object
# 3 Name     VenusaurMega Venusaur
# Speed                       80
# Name: 3, dtype: object
# 4 Name     Charmander
# Speed            65
# Name: 4, dtype: object
# 5 Name     Charmeleon
# Speed            80
# Name: 5, dtype: object
# 6 Name     Charizard
# Speed          100
# Name: 6, dtype: object
# 7 Name     CharizardMega Charizard X
# Speed                          100
# Name: 7, dtype: object
# 8 Name     CharizardMega Charizard Y
# Speed                          100
# Name: 8, dtype: object
# 9 Name     Squirtle
# Speed          43
# Name: 9, dtype: object
# 10 Name     Wartortle
# Speed           58
# Name: 10, dtype: object
# 11 Name     Blastoise
# Speed           78
# Name: 11, dtype: object
# 12 Name     BlastoiseMega Blastoise
# Speed                         78
# ...

# %% [markdown]
# # Sorting / Describing Data

# %%
import pandas as pd
df = pd.read_csv('pokemon_data.csv')

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df.sort_values('Name',ascending=False)
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 46    41                    Zubat   Poison  Flying   40      45       35
# 631  570                    Zorua     Dark     NaN   40      65       40
# 632  571                  Zoroark     Dark     NaN   60     105       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# 392  359                    Absol     Dark     NaN   65     130       60
# 68    63                     Abra  Psychic     NaN   25      20       15
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 510  460                Abomasnow    Grass     Ice   90      92       75
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1','HP'],ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Making Changes to the data

# %%
df['Total']=df['HP']+df['Attack']+df['Defense']+df['Speed']


df.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    188
# ...

# %%
df.drop(columns=['Total'])
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df['Total']=df.iloc[:,4:10].sum(axis=1)

df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# # Saving Data file

# %%
df.to_csv('modified.csv')

# %%
df.to_excel('modified.xlsx')

# %%
df.to_csv('modified.csv',sep='\t')

# %% [markdown]
# # Filtering Data

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1    Type 2   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison   45      49       49
# 1      2                Ivysaur  Grass    Poison   60      62       63
# 2      3               Venusaur  Grass    Poison   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison   80     100      123
# 16    13                 Weedle    Bug    Poison   40      35       30
# ..   ...                    ...    ...       ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN   56      61       65
# 719  651              Quilladin  Grass       NaN   61      78       95
# 720  652             Chesnaught  Grass  Fighting   88     107      122
# 740  672                 Skiddo  Grass       NaN   66      65       48
# 741  673                 Gogoat  Grass       NaN  123     100       62
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df['HP']> 50
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797     True
# 798     True
# 799     True
# Name: HP, Length: 800, dtype: bool

# %%
new_df=pd.read_csv('modified.csv')
new_df.reset_index(drop=True, inplace=True)
new_df
# Out:
#     \t#\tName\tType 1\tType 2\tHP\tAttack\tDefense\tSp. Atk\tSp. Def\tSpeed\tGeneration\tLegendary\tTotal
# 0    0\t1\tBulbasaur\tGrass\tPoison\t45\t49\t49\t65...
# 1    1\t2\tIvysaur\tGrass\tPoison\t60\t62\t63\t80\t...
# 2    2\t3\tVenusaur\tGrass\tPoison\t80\t82\t83\t100...
# 3    3\t3\tVenusaurMega Venusaur\tGrass\tPoison\t80...
# 4    4\t4\tCharmander\tFire\t\t39\t52\t43\t60\t50\t...
# ..                                                 ...
# 795  795\t719\tDiancie\tRock\tFairy\t50\t100\t150\t...
# 796  796\t719\tDiancieMega Diancie\tRock\tFairy\t50...
# 797  797\t720\tHoopaHoopa Confined\tPsychic\tGhost\...
# 798  798\t720\tHoopaHoopa Unbound\tPsychic\tDark\t8...
# 799  799\t721\tVolcanion\tFire\tWater\t80\t110\t120...
#
# [800 rows x 1 columns]

# %% [markdown]
# # Aggregate Statistics(Groupby)

# %%
import pandas as pd
df= pd.read_csv('pokemon_data.csv')
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #         HP      Attack     Defense    Sp. Atk    Sp. Def  \
# Type 1
# Steel     442.851852  65.222222   92.703704  126.370370  67.518519  80.629630
# Rock      392.727273  65.363636   92.863636  100.795455  63.340909  75.477273
# Dragon    474.375000  83.312500  112.125000   86.375000  96.843750  88.843750
# Ground    356.281250  73.781250   95.750000   84.843750  56.468750  62.750000
# Ghost     486.500000  64.437500   73.781250   81.187500  79.343750  76.468750
# Water     303.089286  72.062500   74.151786   72.946429  74.812500  70.517857
# Ice       423.541667  72.000000   72.750000   71.416667  77.541667  76.291667
# Grass     344.871429  67.271429   73.214286   70.800000  77.500000  70.428571
# Bug       334.492754  56.884058   70.971014   70.724638  53.869565  64.797101
# Dark      461.354839  66.806452   88.387097   70.225806  74.645161  69.516129
# Poison    251.785714  67.250000   74.678571   68.821429  60.428571  64.392857
# ...

# %%
import pandas as pd
df= pd.read_csv('modified.csv',sep='\t')
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  HP  Attack  \
# 0             0    1              Bulbasaur    Grass  Poison  45      49
# 1             1    2                Ivysaur    Grass  Poison  60      62
# 2             2    3               Venusaur    Grass  Poison  80      82
# 3             3    3  VenusaurMega Venusaur    Grass  Poison  80     100
# 4             4    4             Charmander     Fire     NaN  39      52
# ..          ...  ...                    ...      ...     ...  ..     ...
# 795         795  719                Diancie     Rock   Fairy  50     100
# 796         796  719    DiancieMega Diancie     Rock   Fairy  50     160
# 797         797  720    HoopaHoopa Confined  Psychic   Ghost  80     110
# 798         798  720     HoopaHoopa Unbound  Psychic    Dark  80     160
# 799         799  721              Volcanion     Fire   Water  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#           Unnamed: 0           #         HP      Attack     Defense  \
# Type 1
# Steel     486.296296  442.851852  65.222222   92.703704  126.370370
# Rock      431.840909  392.727273  65.363636   92.863636  100.795455
# Dragon    521.843750  474.375000  83.312500  112.125000   86.375000
# Ground    392.312500  356.281250  73.781250   95.750000   84.843750
# Ghost     536.281250  486.500000  64.437500   73.781250   81.187500
# Water     333.312500  303.089286  72.062500   74.151786   72.946429
# Ice       465.666667  423.541667  72.000000   72.750000   71.416667
# Grass     380.414286  344.871429  67.271429   73.214286   70.800000
# Bug       368.072464  334.492754  56.884058   70.971014   70.724638
# Dark      507.387097  461.354839  66.806452   88.387097   70.225806
# Poison    278.285714  251.785714  67.250000   74.678571   68.821429
# Fire      360.942308  327.403846  69.903846   84.769231   67.769231
# Psychic   420.105263  380.807018  70.631579   71.456140   67.684211
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug            25397  23080  3925    4897     4880     3717     4471   4256
# Dark           15729  14302  2071    2740     2177     2314     2155   2361
# Dragon         16699  15180  2666    3588     2764     3099     2843   2657
# Electric       17626  15994  2631    3040     2917     3961     3243   3718
# Fairy           8407   7642  1260    1046     1117     1335     1440    826
# Fighting       10812   9824  1886    2613     1780     1434     1747   1784
# Fire           18769  17025  3635    4408     3524     4627     3755   3871
# Flying          2986   2711   283     315      265      377      290    410
# Ghost          17161  15568  2062    2361     2598     2539     2447   2059
# Grass          26629  24141  4709    5125     4956     5425     4930   4335
# Ground         12554  11401  2361    3064     2715     1807     2008   2045
# ...

# %%
df.groupby(['Type 1']).count()
# Out:
#           Unnamed: 0    #  Name  Type 2   HP  Attack  Defense  Sp. Atk  \
# Type 1
# Bug               69   69    69      52   69      69       69       69
# Dark              31   31    31      21   31      31       31       31
# Dragon            32   32    32      21   32      32       32       32
# Electric          44   44    44      17   44      44       44       44
# Fairy             17   17    17       2   17      17       17       17
# Fighting          27   27    27       7   27      27       27       27
# Fire              52   52    52      24   52      52       52       52
# Flying             4    4     4       2    4       4        4        4
# Ghost             32   32    32      22   32      32       32       32
# Grass             70   70    70      37   70      70       70       70
# Ground            32   32    32      19   32      32       32       32
# Ice               24   24    24      11   24      24       24       24
# ...

# %%
df['count']=1
df.groupby(['Type 1']).count()['count']
# Out:
# Type 1
# Bug          69
# Dark         31
# Dragon       32
# Electric     44
# Fairy        17
# Fighting     27
# Fire         52
# Flying        4
# Ghost        32
# Grass        70
# Ground       32
# Ice          24
# Normal       98
# Poison       28
# Psychic      57
# Rock         44
# Steel        27
# Water       112
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2','HP']).count()['count'].head(15)
# Out:
# Type 1  Type 2    HP
# Bug     Electric  50    1
#                   70    1
#         Fighting  80    2
#         Fire      55    1
#                   85    1
#         Flying    30    1
#                   40    1
#                   55    1
#                   60    2
#                   61    1
#                   65    2
#                   70    4
#                   80    1
#                   86    1
#         Ghost     1     1
# Name: count, dtype: int64

# %%
df.groupby(['Type 1','Type 2','HP']).count().head(15)
# Out:
#                     Unnamed: 0  #  Name  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 1 Type 2   HP
# Bug    Electric 50           1  1     1       1        1        1        1
#                 70           1  1     1       1        1        1        1
#        Fighting 80           2  2     2       2        2        2        2
#        Fire     55           1  1     1       1        1        1        1
#                 85           1  1     1       1        1        1        1
#        Flying   30           1  1     1       1        1        1        1
#                 40           1  1     1       1        1        1        1
#                 55           1  1     1       1        1        1        1
#                 60           2  2     2       2        2        2        2
#                 61           1  1     1       1        1        1        1
#                 65           2  2     2       2        2        2        2
# ...

# %%
df=pd.read_csv('pokemon_data.csv')
df.groupby(['Type 1','Type 2']).count().head(30)
# Out:
#                     #  Name  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1   Type 2
# Bug      Electric   2     2   2       2        2        2        2      2
#          Fighting   2     2   2       2        2        2        2      2
#          Fire       2     2   2       2        2        2        2      2
#          Flying    14    14  14      14       14       14       14     14
#          Ghost      1     1   1       1        1        1        1      1
#          Grass      6     6   6       6        6        6        6      6
#          Ground     2     2   2       2        2        2        2      2
#          Poison    12    12  12      12       12       12       12     12
#          Rock       3     3   3       3        3        3        3      3
#          Steel      7     7   7       7        7        7        7      7
#          Water      1     1   1       1        1        1        1      1
# ...

# %%
df.groupby(['Type 2','Speed']).count().head(30)
# Out:
#               #  Name  Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Type 2 Speed
# Bug    45     1     1       1   1       1        1        1        1
#        65     1     1       1   1       1        1        1        1
#        75     1     1       1   1       1        1        1        1
# Dark   35     1     1       1   1       1        1        1        1
#        55     2     2       2   2       2        2        2        2
#        58     1     1       1   1       1        1        1        1
#        60     1     1       1   1       1        1        1        1
#        61     1     1       1   1       1        1        1        1
#        65     2     2       2   2       2        2        2        2
#        71     1     1       1   1       1        1        1        1
#        74     2     2       2   2       2        2        2        2
#        80     2     2       2   2       2        2        2        2
# ...
